# %%
sentence = input()
space = " " # Define space as a single space character
num_words = sentence.count(space) + 1 # Add 1 to the count of spaces to get the word count
print(num_words)
# Out:
#  moiz is very bad boy with goods heart
# 8
