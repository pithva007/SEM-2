# %%
list=['khush',164,99.09,'kshushi']
print(list)
# Out:
# ['khush', 164, 99.09, 'kshushi']

# %%
list[0]='khushi'

# %%
print(list)
# Out:
# ['khushi', 164, 99.09, 'kshushi']

# %%
list[1,2,3]='kh','uh','hi'
list=['khush',164,99.09,'kshushi']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 list[1,2,3]='kh','uh','hi'
#       2 print(list)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
list[1:2:3]='kh','uh','hi'
print(list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 list[1:2:3]='kh','uh','hi'
#       2 print(list)
#
# ValueError: attempt to assign sequence of size 3 to extended slice of size 1

# %%
list=['khush',164,99.09,'kshushi',89,"hello"]
list[1,2,3]='kh','uh','hi'
print(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 list=['khush',164,99.09,'kshushi',89,"hello"]
# ----> 2 list[1,2,3]='kh','uh','hi'
#       3 print(list)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
list=['khush',164,99.09,'kshushi',89,"hello"]
list[1;2;3]='kh','uh','hi'
print(list)
# Out:
#   Cell In[7], line 2
#     list[1;2;3]='kh','uh','hi'
#           ^
# SyntaxError: invalid syntax

# %%
list=['khush',164,99.09,'kshushi',89,"hello"]
list[1:2:3]='kh','uh','hi'
print(list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 list=['khush',164,99.09,'kshushi',89,"hello"]
# ----> 2 list[1:2:3]='kh','uh','hi'
#       3 print(list)
#
# ValueError: attempt to assign sequence of size 3 to extended slice of size 1

# %%
list=['khush',164,99.09,'kshushi',89,"hello"]
list[1:3]='kh','uh','hi'
print(list)
# Out:
# ['khush', 'kh', 'uh', 'hi', 'kshushi', 89, 'hello']

# %%
a, b, c=eval(input('Enter a, b, c:'))
# Out:
# Enter a, b, c: khush pithva is
# Traceback (most recent call last):
#
#   File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[11], line 1
#     a, b, c=eval(input('Enter a, b, c:'))
#
#   File <string>:1
#     khush pithva is
#           ^
# SyntaxError: invalid syntax

# %%
 c=eval(input(“Enter a, b, c:”))

# %%
 a=eval(input("Enter three values:"))
# Out:
# Enter three values: 24 54 23
# Traceback (most recent call last):
#
#   File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[13], line 1
#     a=eval(input("Enter three values:"))
#
#   File <string>:1
#     24 54 23
#        ^
# SyntaxError: invalid syntax

# %%
 a=eval(input("Enter three values:"))
# Out:
# Enter three values: 23

# %%
 a,b,c=eval(input('Enter a, b, c:'))
# Out:
# Enter a, b, c: 24
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a,b,c=eval(input('Enter a, b, c:'))
#
# TypeError: cannot unpack non-iterable int object

# %%
 a,b,c=eval(input('Enter a, b, c:'))
# Out:
# Enter a, b, c: 23 43 54
# Traceback (most recent call last):
#
#   File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[17], line 1
#     a,b,c=eval(input('Enter a, b, c:'))
#
#   File <string>:1
#     23 43 54
#        ^
# SyntaxError: invalid syntax

# %%
 a,b,c=eval(input('Enter a, b, c:'))
# Out:
# Enter a, b, c: 1,2,3

# %%
 a,b,c=eval(input('Enter a, b, c:'))
# Out:
# Enter a, b, c: 10+5,10*5,10/5

# %%
print(a,b,c)
# Out:
# 15 50 2.0
