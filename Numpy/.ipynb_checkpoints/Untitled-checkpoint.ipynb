# %%
import numpy as np

list1=[]



n=int(input("enter the dimention of array:" ))
m=int(input())
for i in range(0,n+1):
    for i in range(0,m+1):
        data=int(input("enter data of ")
        list1.append(data)
a=np.array(list1)
# Out:
#   Cell In[7], line 11
#     data=int(input("enter data of ",j)
#             ^
# SyntaxError: '(' was never closed
