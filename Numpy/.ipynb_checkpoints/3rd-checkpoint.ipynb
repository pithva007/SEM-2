# %%
str='khush pithva'
print(str*2)
# Out:
# khush pithvakhush pithva

# %%
str='khush pithva'
print(str+ 'test')
# Out:
# khush pithvatest

# %%
str='khush pithva'
print(str+' ' + 'test')
# Out:
# khush pithva test

# %%
str='khush pithva'
print(str(-1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 str='khush pithva'
# ----> 2 print(str(-1))
#
# TypeError: 'str' object is not callable

# %%
str='khush pithva'
print(str[-1])
# Out:
# a

# %%
str='khush pithva'
print(str[-1:3])

# %%
str='khush pithva'
print(str[-1:3])

# %%
str='khush pithva'
print(str[-1:3])

# %%
str='khush pithva'
print(str[-3:-1])
# Out:
# hv

# %%
str='khush pithva'
print(str[-3:-2])
# Out:
# h

# %%
str='hello world'
print(str[-1:-3])
# Out:
# rl

# %%
str='hello world'
print(str[-1:-3])

# %%
str='hello world'
print(str[-3:-1])
# Out:
# rl

# %%
str='hello world'
print(str[-3:0])

# %%
list=['abcd',786,2.23,'khush',70.2]
print(list[3])
# Out:
# khush

# %%
print(list[0])
# Out:
# abcd

# %%
print(str[-2])
# Out:
# l

# %%
print(str[-3])
# Out:
# r

# %%
print(str[-4])
# Out:
# o

# %%
tinylist=[12,'khushi','hiii',89.98]
print(list[3]+' loves  '+tinylist[1])
# Out:
# khush loves  khushi
