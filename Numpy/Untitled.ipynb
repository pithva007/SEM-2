# %%
from numpy import*
import statics
list1=[]



n=int(input("enter the dimention of array:" ))
m=int(input())
for i in range(1,n+1):
    row=[]
    for i in range(1,m+1):
        data=int(input("enter data of "))
        row.append(data)
    list1.append(row)
a=array(list1)
print(a)
print("mean : ",mean(a))
print("std : ",std(a))
print("var : ",var(a))
print("sum : ",sum(a))
print("prod : ",prod(a))
print("sumsum : ",cumsum(a))
print("cumprod : " ,cumprod(a))
print("min : " ,min(a))
print("max : ",max(a))
# Out:
# enter the dimention of array: 3
#  1
# enter data of  1
# enter data of  2
# enter data of  3
# [[1]
#  [2]
#  [3]]
# mean :  2.0
# std :  0.816496580927726
# var :  0.6666666666666666
# sum :  6
# prod :  6
# sumsum :  [1 3 6]
# cumprod :  [1 2 6]
# min :  1
# max :  3

# %%
import random

def main():
    min_val, max_val = 1, 6
    secret_number = random.randint(min_val, max_val)
    
    print("Welcome to the Number Guessing Game!")
    print("The number on DICE is : ",secret_number)
   

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Number Guessing Game!
# The number on DICE is :  4

# %%
import random

def main():
    min_val, max_val = 1, 6
    secret_number = random.randint(min_val, max_val)
    
    print("Welcome to the Number Guessing Game!")
    if secret_number%2==0:
        print("Head")
    else:
        print("Tail")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Number Guessing Game!
# Head

# %%
#mean
n=int(input
