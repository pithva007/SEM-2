# %%
n=int(input('Enter how many numbers do you want to work with'))
mylist=[]
for i in range(n):
    num=float(input('Enter number'+str(i+1)+':'))
    mylist.append(num)
print(mylist)
# Out:
# Enter how many numbers do you want to work with3
# Enter number1:1
# Enter number2:6
# Enter number3:5
# [1.0, 6.0, 5.0]

# %%
#Statistical measures using library
import numpy as np
import scipy as st
import statistics as st
n=int(input('Enter how many numbers do you want to work with'))
mylist=[]
#Mean
for i in range(n):
    num=float(input('Enter number'+str(i+1)+':'))
    mylist.append(num)
myarr=np.array(mylist)
avg=np.mean(myarr)
print('The mean of the data is :',avg)
#Variance
print('Variance',np.var(myarr))
#Standard deviation
print('Standard deviation:',np.std(myarr))
#Median
print('Median:',np.median(myarr))
#Mode
print('Mode:',st.mode(myarr))
#Range
mini=np.min(myarr)
maxi=np.max(myarr)
range1=maxi-mini
print('Range:',range1)
# Out:
# Enter how many numbers do you want to work with5
# Enter number1:1
# Enter number2:2
# Enter number3:3
# Enter number4:4
# Enter number5:5
# The mean of the data is : 3.0
# Variance 2.0
# Standard deviation: 1.4142135623730951
# Median: 3.0
# Mode: 1.0
# Range: 4.0

# %%
#Statistical measures without using library
import numpy as np
n=int(input('Enter the no. of elements do you want to store'))
mylist=[]
for i in range(n):
     num=float(input('Enter number'+str(i+1)+':'))
     mylist.append(num)
myarr=np.array(mylist) 
n1=n
#Mean
x_sum=0
for i in myarr:
    x_sum=i+x_sum
mean=x_sum/n1
print('Mean:',mean)
#Variance
square_sum=0
for i in myarr:
    square_sum+=(i-mean)**2
variance=square_sum/n
print('Variance :',variance)
#Standard deviation
std_dev=np.sqrt(variance)
print('Standard deviation',std_dev)
#Median
for i in range(n-1):
    for j in range(i+1,n):
        if myarr[i]>myarr[j]:
            temp=myarr[i]
            myarr[i]=myarr[j]
            myarr[j]=temp
print(myarr)
if(n%2==0):
   med=(myarr[int((n/2)-1)]+myarr[int(n/2)])/2
else:
   med=myarr[n//2]
print('Median:',med)
#Range
min1=myarr[0]
max1=myarr[-1]
range1=max1-min1
print('Range is :',range1)
#Mode
frequency={}
for i in myarr:
    if i in frequency:
        frequency[i]+=1
    else:
        frequency[i]=1
mode_freq=1
for i in frequency.values():
    if i>mode_freq:
        mode_freq=i
mode=[]
for i in frequency:
    if frequency[i]==mode_freq:
        mode.append(i)
if mode_freq==1:
    print('Mode does not exist for given data')
else:
    print('Mode :',mode)
# Out:
# Enter the no. of elements do you want to store4
# Enter number1:1
# Enter number2:2
# Enter number3:3
# Enter number4:4
# Mean: 2.5
# Variance : 1.25
# Standard deviation 1.118033988749895
# [1. 2. 3. 4.]
# Median: 2.5
# Range is : 3.0
# Mode does not exist for given data

# %%
import sys
from collections import Counter

def solve():
    n = int(sys.stdin.readline())
    
    a = list(map(int, sys.stdin.readline().split()))

    counts = Counter(a)
  
    
    can_guarantee = False

    for count in counts.values():
        if count >= 4:
            can_guarantee = True

            break
            
    if can_guarantee:
        print("Yes")
    else:
        print("No")

t = int(sys.stdin.readline())
for _ in range(t):
    solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 70
#      67         print("No")
#      69 # Read the total number of test cases from the first line of input.
# ---> 70 t = int(sys.stdin.readline())
#      71 # Loop through each test case and solve it.
#      72 for _ in range(t):
#
# ValueError: invalid literal for int() with base 10: ''
